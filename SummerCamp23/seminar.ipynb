# %% [markdown]
# 2022/09/20
# Klynoroales Aguilar
# 22100324

# %% [markdown]
# # Interpretations

# %% [markdown]
# ### **[Interpretaiton in Chapter2 - Datamanagement in Python]**
# - **2.1 - Variables and name rules**
#     - To begin, this chapter has reviewed our understanding of basic data in python. Types of data types include int, float, bool, and str. We could also review naming conventions.
# - **2.2 ~ 2.3 - Whitespace ~ Comments**7
#     - Python learned the need to recognize spaces correctly and how to comment out
# - **2.4 - Mathematical operatrions**
#     - Reviewed the four arithmetic operations and definitions in Python.
# - **2.5 ~ 2.7 - Two libraries: Pandas and NumPy ~ Data description and calculation**
#     -  The students learned about Pandas and NumPy, libraries commonly used to work with data in Python. The main focus was on how to read data and its display, as well as the calculation and display of key indicators to get an overview of the data.
# - **2.8 ~ 2.9 - An example: calculating summary statstics for house prices**
#     - First, data.describe() was run to get an overview of the data, from which the mean, standard deviation, minimum, and maximum were examined to better understand the data. Next, kurtosis and skewness were examined by using skew() and .kurtosis(). As a result, the skewness was -0.1114, indicating that the graph is shifted to the right from the center (0). Therefore, the use of LogDiff made it easier to understand the graph by transforming it logarithmically and making it closer to a normal distribution.

# %% [markdown]
# ### **[Interpretaiton in Chapter3 - Simple Linear regression - estimation of an optimal hedge ratio]**
# - The time series data for an index's actual price, referred to as the "spot," and its futures price, labeled as "futures," is captured at one-month intervals over several years. Ordinary Least Squares (OLS) regression is then employed to find the estimates for the coefficients 'a' and 'b' in the linear equation, where the spot price is the dependent variable and futures price is the independent variable. The resulting equation is Spot = -2.8378 + 1.0016 * futures + u, where 'u' is a normally-distributed random error term with a mean of zero. The R-squared value for this model is 1, indicating a perfect fit to the data. The analysis also provides t-scores and p-values for significance testing. The t-score for the intercept 'a' is -1.906, which is relatively low. Consequently, we might fail to reject the null hypothesis that 'a' equals zero. On the other hand, the t-score for the coefficient 'b' is extremely high at 1002.231, leading us to likely reject the null hypothesis that 'b' equals zero. The p-values further confirm this: the p-value for 'a' is just above the commonly-used 5% significance level, so the null hypothesis for 'a' is likely not rejected. In contrast, the p-value for 'b' is virtually zero, suggesting that the null hypothesis for 'b' is rejected, likely at a 1% significance level.

# %% [markdown]
# ### **[Interpretaiton in Chapter4 - Hypothis testing - Example1: hedging revisited]**
# - The code in the subsequent section runs an F-test based on the index pricing data discussed earlier. The null hypothesis for this test posits that the coefficient for futures, represented by 'β' in the equation, is equal to 1. The F-test generates an F-score of 2.58, which can be evaluated against the critical F-value for a chosen significance level. The degrees of freedom are specified in the result: 'df_denom' for the denominator and 'df_num' for the numerator. In this example, Python is utilized to find the critical F-value due to the large degree of freedom for the denominator. The critical F-value at a 0.05 significance level turned out to be 3.88. Since the calculated F-score of 2.58 is below this value, we fail to reject the null hypothesis at the 0.05 significance level. Additionally, the test's P-value is 0.1, which is higher than most commonly used significance levels. Consequently, the null hypothesis that the coefficient for futures is 1 is not rejected.

# %% [markdown]
# ### **[Interpretaiton in Chapter5 - Estimation and hypothesis testing - Example 2: the CAPM]**
# - The "capm.xlsx" Excel file contains historical data on five market investments and a risk-free asset, which is used for analysis in a Python script. The code calculates log returns for the S&P 500 and Ford, subtracting the risk-free rate (a U.S. Treasury bill) from each. For the S&P 500, this difference is considered the market risk premium.
#
# - Graphs and scatter plots reveal a slight positive correlation between Ford and the S&P 500. Ford is more reactive to market changes, showing higher rates of change.
#
# - Using Ordinary Least Squares (OLS), a linear regression model is fitted with Ford's excess return as the dependent variable and the S&P 500's excess return as the independent variable. The resulting coefficient for α is -0.9560, which is not statistically significant based on its t-score and p-value. This suggests Ford's return is mainly influenced by its market risk premium. The coefficient β is 1.8898, confirmed as highly significant by its t-score and p-value. This high β value highlights Ford's sensitivity to market movements.

# %% [markdown]
# ### **[Interpretaiton in Chapter6 - Sample output for multiple hypothesis tests]**
# - The subsequent code segment retrieves results saved in a file called "capm.pickle," which contains the findings from the previous analysis. This time, an F-test is performed to investigate whether both α and β coefficients are equal to 1. This is specified in the code through the expression 'hypotheses = ‘erford = intercept = 1’. The F-statistic for a 1% critical value is 4.72. However, the computed F-score is 12.94, and the p-value is close to zero. These results strongly indicate a rejection of the null hypothesis that both α and β are equal to 1. This outcome aligns with expectations, particularly because β had already been shown not to be 1 in the prior analysis.

# %% [markdown]
# ### **[Interpretaiton in Chapter7 - Muliple regression using an APT - style moled]**
#
# #### APT
#
# - The forthcoming code develops an Arbitrage Pricing Theory (APT) model to forecast Microsoft's returns, incorporating various economic indicators like S&P500, CPI, IPI, M1 money supply, and consumer credit. The model also includes returns on U.S. Treasury bills to calculate a credit spread between AAA and BAA bonds.
#
# - The model focuses on unexpected changes in these variables, assuming that consumers expect future stability. The calculations for these unexpected changes are performed in subsequent code sections.
#
# - The APT equation sums up these risk factors to predict Microsoft's returns, utilizing OLS regression for coefficient determination. Notably, the 'rterm' variable, likely reflecting yield spread changes, has the most significant impact.
#
# - An F-test is conducted to evaluate the significance of four economic indicators. The F-score and a p-value of 0.8 suggest that these variables are not statistically significant, failing to reject the null hypothesis.
#
# #### Step-wize
#
# - Given that the initial regression included various factors that lacked statistical significance, a step-wise regression technique is used to refine the formula for Microsoft's expected return, incorporating only impactful variables. A one-way forward selection method is utilized here, a kind of forward stepwise regression that sequentially adds variables according to their statistical significance. The p-value serves as the criterion for selection; the lower the p-value, the more significant the variable. The algorithm picks the most significant variable first and continues to add variables until it encounters those with p-values exceeding 0.2, at which point they are removed from consideration.
#
# - Due to inaccuracies in my Python code, the step-wise regression incorrectly incorporated 'mustb3m' and 'inflation,' which were not intended elements of the original APT model. The accurate model should have contained only 'ersandp,' 'rterm,' and 'dinflation.'
#
# - Although the final output is compromised by these coding errors, the adjusted R-squared value, which can be derived from a different code segment, is 0.343. This implies that the erroneous model, despite its shortcomings, is still capable of accounting for roughly 34.3% of the variation in the dependent variable.

# %% [markdown]
# ### **[Interpretaiton in Chapter8 - Quantile regression]**
# - The subsequent code extracts the previously estimated CAPM formula for Ford, using the S&P500 as the independent variable. A quantile regression model is then constructed, focusing on Ford's expected returns at the 50th percentile.
#
# - Efficient estimates for various quantiles can be generated by changing the value of the quantile parameter, 'q,' in the code. For example, the code begins with a 'q' value of 0.5 and can be adjusted to values ranging from 0.1 to 1.0 in 0.1 increments, as specified in the code.
#
# - Due to the lengthy nature of the results, key outputs such as the intercept coefficient (α), the S&P500 excess return coefficient (β), as well as the lower and upper bounds of the 95% confidence interval, are consolidated into a single table. The code also presents the model's fitted values for 'y' across different percentiles. While lower quantiles are naturally expected to have lower α values, interestingly, β is significantly higher only at the 10th percentile. This suggests that when Ford's excess returns are lower, they are much more responsive to fluctuations in the S&P500's excess returns, indicating Ford's susceptibility to extreme market events.
#
# - The outcomes of the quantile regression can also be visually represented through plotting. In the graphical output, the 50th percentile regression line is color-coded red, while the others are in gray. The graphical data align with the numerical values tabulated previously; the intercepts for the percentiles ascend from the 10th to the 90th percentile, with the 10th percentile showing the steepest beta or slope value.

# %% [markdown]
# ### **[Interpretaiton in Chapter9 - Calculating principal components]**
#
# #### PCA
# - Monthly bond returns from various maturities are imported into a Jupyter Notebook from an Excel file. Using Python, the data is organized into a matrix 'M' and standardized by zero-centering and scaling.
#
# - Python code calculates the covariance matrix, eigenvalues, and eigenvectors, with the resulting table showcasing each bond's influence on each principal component (PC).
#
# - The code also calculates the proportion of total variance explained by each PC. The first PC accounts for 97% of the data variation, nearly reaching 100% with the second PC. This enables two-dimensional graphical representation of the data using these two principal components.

# %% [markdown]
# ### **[Interpretaiton in Chapter10 - Diagnostic testing]**
# - **10.1 - Testing for heteroscedasticity**
#     - The data from 'macro.pickle,' used for the Arbitrage Pricing Theory (APT) regression analysis on Microsoft's excess return, is revisited to test for heteroskedasticity. Although the original OLS regression results are not in the file, the model is rebuilt using Python. The code checks for heteroskedasticity in the residuals, primarily through the Lagrange multiplier statistic and the F-score. Both tests yield a p-value of 0.87, supporting the null hypothesis that there is no heteroskedasticity in the model's residuals, thereby affirming the reliability of the regression analysis.
#
# - **10.2 - Using White's modified standard error estimates**
#     - Even if no heteroskedasticity was identified in the existing model, utilizing White's modified standard error for coefficient estimates could offer added robustness, especially given that the Arbitrage Pricing Theory (APT) regression model has an unusually large number of coefficients. While no significant alterations in the standard errors were observed when compared to the original regression outcomes (found in Chapter 7), the advantages of using heteroskedasticity-robust standard errors become apparent through an enhanced t-score and a reduced p-value.
#
# - **10.3 - The Newey-West procedure for estimating standard errors**
#     - The Newey-West approach is employed in the following code to both identify heteroskedasticity and calculate standard errors that are resilient to autocorrelation in the residuals. Much like the method for applying White's modified standard errors, the Newey-West procedure is activated by specifying 'HAC' after 'cov-type=' in the code. The number of lags is then defined in the subsequent line, allowing the model to account for potential autocorrelation extending up to the previous six months.
#
# - **10.4 - Autoccorrelation and dynamic models**
#     - The Durbin-Watson test and the Breusch-Godfrey test are used to examine autocorrelation in the residuals of an APT regression model. The Durbin-Watson test yields a value of 2.10, indicating short-term mean reversion or a negative relationship between consecutive residuals. The Breusch-Godfrey test, set with a 10-month lag, reveals a p-value of approximately 0.9, suggesting negligible or no autocorrelation over that time frame. Overall, there's limited evidence for significant autocorrelation in the residuals.
#
# - **10.5 - Testing for non-normality**
#     - The macro.pickle data is analyzed to check if residuals follow a normal distribution. Although the histogram suggests a bell curve, outliers and higher-valued residuals hint at skewness and kurtosis. The Jarque-Bera test confirms these observations, strongly refuting the null hypothesis of a normal distribution. This indicates potential negative skewness and leptokurtosis in the residual distribution.
#
# - **10.6 - Dummy variables construction and use**
#     - The data from the macro.pickle file is graphed to identify outliers in the residuals for Microsoft's excess return, specifically around the years 2000 and 2001. To mitigate their impact, two binary dummy variables are introduced that neutralize these outliers on their specific dates. These variables significantly improve the model's fit, as evidenced by low p-values and a slight increase in the adjusted R-squared value.
#
# - **10.7 - Multicollinearity**
#     - The macro.pickle data is also analyzed for multicollinearity within the ATP regression model by examining correlations among the independent variables via a correlation matrix. Apart from the main diagonal, which naturally holds values of 1, there seems to be no significant correlation between the independent variables.
#
# - **10.8 - The RESET test for functional form**
#     - To probe whether the ATP regression model from macro.pickle omits any crucial non-linear variables, the RESET test is applied. This test is set with four degrees of freedom, allowing for the incorporation of terms up to the fourth order. The test yields an f-score with a p-value not sufficiently low to reject the null hypothesis, suggesting that no additional variables are required. Moreover, the f-score is lower compared to that of the original model, indicating that the new variables would make the model's fit worse, not better. Thus, it can be concluded that the original ATP regression model adequately accounts for all necessary risk factors.
#
# - **10.9 - Stability tests**
#     - In the regression model derived from the macro.pickle file, the Chow test for known structural breaks is executed with a designated break point at January 1, 1996. The f-statistic value is manually computed in the code, considering variables like the residual sum of squares, degrees of freedom, and the count of observations. The resulting f-statistic stands at 1.99. In this scenario, the degrees of freedom are calculated using k_total, representing the aggregate number of parameters in the full regression model. These degrees of freedom then help determine a 10% critical value using Python. Although a 10% threshold might be considered high, it supports the rejection of the null hypothesis, asserting that the parameters remain stable across the two sub-samples.
#
#     - Following this, the CUSUM test is carried out to check for structural breaks without pre-specified points. The test statistic is found to be significant at a 5% critical value, corroborating the results of the Chow test and thereby refuting the null hypothesis of no structural changes.
#
#     - Additionally, recursive estimation is used as another technique to identify unknown structural breaks. Here, the initial sample size is fixed at 11, and a total of 373 iterations are performed. This equates to 374 parameter adjustments, including the first data addition not covered in the iterations. A graph is plotted to showcase the time-adjusted parameters, which includes standard error bands alongside the estimated beta values. Initially, there's noticeable instability, which can be attributed to the small sample size and its outsized impact on the model. However, as more data points are incorporated, the beta parameter starts to stabilize.

# %% [markdown]
# # - OUTPUTS -
# - All outputs in the first half were done manually. However, since there were many bugs after Chapter 10, and the number of pages in the pdf was almost 80p when showing the bugs, we substituted markDown notation for the code after Chapter 10.

# %% [markdown]
# # 2 Data management in Python

# %% [markdown]
# ## 2.1 Variables and name rules

# %%
a = 1
type(a)
# Out:
# int

# %%
a = 1.2
type(a)
# Out:
# float

# %%
b = True
c = False
type(b)
# Out:
# bool

# %%
type(c)
# Out:
# bool

# %%
date = '31/12/2016'
type(date)
# Out:
# str

# %%
a=7
a=3
print(a)
# Out:
# 3

# %%
my value = 1
# Out:
#   Cell In[11], line 1
#     my value = 1
#        ^
# SyntaxError: invalid syntax

# %%
myvalue = 1

# %%
my_value = 1

# %%
3value = 1
# Out:
#   Cell In[14], line 1
#     3value = 1
#      ^
# SyntaxError: invalid syntax

# %%
value = 1
Value = 2
print(value)
print(Value)
# Out:
# 1
# 2

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  '__peg_parser__',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# ## 2.2 Whitespace

# %%
def func():
    return print("hello world")
func()
# Out:
# hello world

# %%
def func():
return print('hello world')
func()
# Out:
#   Cell In[21], line 2
#     return print('hello world')
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# ## 2.3 Comments

# %% [markdown]
# ## 2.4 Mathematical operations

# %%
add_two_num = 1 + 2
subtract_two_num = 10 - 2
multiply_two_num = 17*2
divide_two_num = 24/6

print(add_two_num)
print(subtract_two_num)
print(multiply_two_num)
print(divide_two_num)
# Out:
# 3
# 8
# 34
# 4.0

# %%
my_data = 12
def func(x):
    y = x**2
    return y
func(my_data)
# Out:
# 144

# %% [markdown]
# ## 2.5 Two Libraries: Pandas and NumPy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2.6 Data input and saving

# %%
data = pd.DataFrame(
    data={'Year': np.array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]), 
          'Risky Ricky': np.array([24, 18, 4, -23, -12, 1, 7, 12, -6, -14, -7, 56, 14]),
          'Safe Steve': np.array([9, 7, 5, -8, -3, 3, 4, 2, 3, 6, 2, 19, 12]),
          'Ricky Ranks': np.array([2, 3, 7, 13, 11, 8, 6, 5, 9, 12, 10, 1, 4]),
          'Steve Ranks': np.array([3, 4, 6, 13, 12, 8, 7, 10, 8, 5, 10, 1, 2])
         }
)

# %% [markdown]
# ## 2.7 Data description and calculation

# %%
print(data)
# Out:
#     Year  Risky Ricky  Safe Steve  Ricky Ranks  Steve Ranks
# 0   2005           24           9            2            3
# 1   2006           18           7            3            4
# 2   2007            4           5            7            6
# 3   2008          -23          -8           13           13
# 4   2009          -12          -3           11           12
# 5   2010            1           3            8            8
# 6   2011            7           4            6            7
# 7   2012           12           2            5           10
# 8   2013           -6           3            9            8
# 9   2014          -14           6           12            5
# 10  2015           -7           2           10           10
# 11  2016           56          19            1            1
# 12  2017           14          12            4            2

# %%
print(data['Risky Ricky'].mean(), data['Safe Steve'].mean())
print(data['Risky Ricky'].std(), data['Safe Steve'].std())
print(data['Risky Ricky'].skew(), data['Safe Steve'].skew())
print(data['Risky Ricky'].kurtosis(), data['Safe Steve'].kurtosis())
# Out:
# 5.6923076923076925 4.6923076923076925
# 20.36084729484759 6.612924408366485
# 1.1154523149102482 0.29450652269478483
# 2.1042142637505923 1.4590345079578664

# %%
data.describe()
# Out:
#              Year  Risky Ricky  Safe Steve  Ricky Ranks  Steve Ranks
# count    13.00000    13.000000   13.000000     13.00000    13.000000
# mean   2011.00000     5.692308    4.692308      7.00000     6.846154
# std       3.89444    20.360847    6.612924      3.89444     3.782551
# min    2005.00000   -23.000000   -8.000000      1.00000     1.000000
# 25%    2008.00000    -7.000000    2.000000      4.00000     4.000000
# 50%    2011.00000     4.000000    4.000000      7.00000     7.000000
# 75%    2014.00000    14.000000    7.000000     10.00000    10.000000
# max    2017.00000    56.000000   19.000000     13.00000    13.000000

# %%
data.corr()
# Out:
#                  Year  Risky Ricky  Safe Steve  Ricky Ranks  Steve Ranks
# Year         1.000000     0.142928    0.385059     0.021978    -0.197996
# Risky Ricky  0.142928     1.000000    0.870048    -0.934285    -0.766741
# Safe Steve   0.385059     0.870048    1.000000    -0.796004    -0.944866
# Ricky Ranks  0.021978    -0.934285   -0.796004     1.000000     0.763700
# Steve Ranks -0.197996    -0.766741   -0.944866     0.763700     1.000000

# %%
cashflow = pd.Series(index=[0,1,2,3,4,5], name="Cashflow", data=[-107, 5, 5, 5, 5, 105])
print(cashflow)
np.irr(cashflow)
# Out:
# 0   -107
# 1      5
# 2      5
# 3      5
# 4      5
# 5    105
# Name: Cashflow, dtype: int64
# /var/folders/yb/0fg_8nv17y5fjj0s_tq9clbh0000gn/T/ipykernel_11281/540043468.py:3: DeprecationWarning: In accordance with NEP 32, the function irr was removed from NumPy version 1.20.  A replacement for this function is available in the numpy_financial library: https://pypi.org/project/numpy-financial
#   np.irr(cashflow)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[73], line 3
#       1 cashflow = pd.Series(index=[0,1,2,3,4,5], name="Cashflow", data=[-107, 5, 5, 5, 5, 105])
#       2 print(cashflow)
# ----> 3 np.irr(cashflow)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/__init__.py:287, in __getattr__.<locals>._expired(*args, **kwds)
#     286 def _expired(*args, **kwds):
# --> 287     raise RuntimeError(msg)
#
# ...

# %%
import pandas as pd
import numpy as np


data = pd.read_excel('./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/UKHP.xls', index_col=0)
data.head()
# Out:
#             Average House Price
# Month
# 1991-01-01         53051.721106
# 1991-02-01         53496.798746
# 1991-03-01         52892.861606
# 1991-04-01         53677.435270
# 1991-05-01         54385.726747

# %% [markdown]
# ## 2.8 An example: calculating summary statistics for house prices

# %%
print(data['Average House Price'].mean())
print(data['Average House Price'].std())
print(data['Average House Price'].skew())
print(data['Average House Price'].kurtosis())
# Out:
# 124660.48446512519
# 56387.16566469951
# -0.11014547214986718
# -1.591926785005042

# %%
def LogDiff(x):
    x_diff = 100*np.log(x/x.shift(1))
    return x_diff

data['dhp'] = LogDiff(data['Average House Price'])
data.head()
# Out:
#             Average House Price       dhp
# Month
# 1991-01-01         53051.721106       NaN
# 1991-02-01         53496.798746  0.835451
# 1991-03-01         52892.861606 -1.135343
# 1991-04-01         53677.435270  1.472432
# 1991-05-01         54385.726747  1.310903

# %%
data.describe()
# Out:
#        Average House Price         dhp
# count           327.000000  326.000000
# mean         124660.484465    0.424402
# std           56387.165665    1.114586
# min           49601.664241   -3.464027
# 25%           61654.141609   -0.256025
# 50%          150946.108249    0.447332
# 75%          169239.278727    1.145618
# max          211755.925562    3.731686

# %%
data1 = pd.DataFrame({'dhp':LogDiff(data['Average House Price'])})
data1 = data1.dropna()
data1.head()
# Out:
#                  dhp
# Month
# 1991-02-01  0.835451
# 1991-03-01 -1.135343
# 1991-04-01  1.472432
# 1991-05-01  1.310903
# 1991-06-01  1.318181

# %% [markdown]
# ## 2.9 Plots

# %%
import matplotlib.pyplot as plt

plt.figure(1)
plt.plot(data['Average House Price'], label='hp')

plt.xlabel('Data')
plt.ylabel('Average House Price')
plt.title('Graph')
plt.grid(True)

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(2)
plt.hist(data1['dhp'], 20, edgecolor='black', linewidth=1.2)
plt.xlabel('dhp')
plt.ylabel('Density')
plt.title('Histogram')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 2.10 Saving data and results

# %% [markdown]
# data.to_excel('./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/UKHP.xls')

# %% [markdown]
# import pickle
# with open('UKHP.pickle', 'wb') as handle:
#     pickle.dump(data, handle)

# %% [markdown]
# # 3 Simple Linear regression - estimetion of an optimal hedge ratio

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

abspath = './Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/'
data = pd.read_excel(abspath + 'SandPhedge.xls', index_col=0)
data.head()
# Out:
#                   Spot  Futures
# Date
# 1997-09-01  947.280029   954.50
# 1997-10-01  914.619995   924.00
# 1997-11-01  955.400024   955.00
# 1997-12-01  970.429993   979.25
# 1998-01-01  980.280029   987.75

# %%
formula = 'Spot ~ Futures'
results = smf.ols(formula, data).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   Spot   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.005e+06
# Date:                Mon, 18 Sep 2023   Prob (F-statistic):               0.00
# Time:                        13:17:01   Log-Likelihood:                -826.86
# No. Observations:                 247   AIC:                             1658.
# Df Residuals:                     245   BIC:                             1665.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.8378      1.489     -1.906      0.058      -5.771       0.095
# ...

# %%
def LogDiff(x):
    x_diff = 100*np.log(x/x.shift(1))
    x_diff = x_diff.dropna()
    return x_diff

data = pd.DataFrame({'ret_spot' : LogDiff(data['Spot']),
                    'ret_future':LogDiff(data['Futures'])})

data.head()
# Out:
#             ret_spot  ret_future
# Date
# 1997-10-01 -3.508608   -3.247557
# 1997-11-01  4.362145    3.299927
# 1997-12-01  1.560914    2.507563
# 1998-01-01  1.009901    0.864266
# 1998-02-01  6.807837    6.159189

# %%
data.describe()
# Out:
#          ret_spot  ret_future
# count  246.000000  246.000000
# mean     0.416776    0.414017
# std      4.333323    4.419049
# min    -18.563647  -18.944697
# 25%     -1.831388   -1.931400
# 50%      0.918522    0.997641
# 75%      3.276468    3.133588
# max     10.230659   10.387184

# %%
formula = 'ret_spot ~ ret_future'
results = smf.ols(formula, data).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               ret_spot   R-squared:                       0.989
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                 2.147e+04
# Date:                Mon, 18 Sep 2023   Prob (F-statistic):          7.54e-240
# Time:                        13:18:07   Log-Likelihood:                -157.16
# No. Observations:                 246   AIC:                             318.3
# Df Residuals:                     244   BIC:                             325.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0131      0.029      0.444      0.658      -0.045       0.071
# ...

# %% [markdown]
# # 4 Hypothis testing - Example1 1: hedging revisited

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf


abspath = './Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/'
data = pd.read_excel(abspath + 'SandPhedge.xls', index_col=0)

# %%
formula = 'Spot ~ Futures'
hypotheses = 'Futures = 1'
results = smf.ols(formula, data).fit()
f_test = results.f_test(hypotheses)
print(f_test)
# Out:
# <F test: F=2.5846385570625636, p=0.10919294686221338, df_denom=245, df_num=1>

# %%
def LogDiff(x):
    x_diff = 100*np.log(x/x.shift(1))
    x_diff = x_diff.dropna()
    return x_diff
data = pd.DataFrame({'ret_spot' : LogDiff(data['Spot']),
                   'ret_future' : LogDiff(data['Futures'])})

# %%
formula = 'ret_spot ~ ret_future'
hypotheses = 'ret_future = 1'

results = smf.ols(formula, data).fit()
f_test = results.f_test(hypotheses)
print(f_test)
# Out:
# <F test: F=14.029809609669563, p=0.00022456631728789324, df_denom=244, df_num=1>

# %% [markdown]
# # 5 Estimation and hypothesis testing - Exampple 2: the CAPM

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

data = pd.read_excel('./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/capm.xls', index_col=0)
data.head()
# Out:
#                   SANDP   FORD         GE  MICROSOFT     ORACLE  USTB3M
# Date
# 2002-01-01  1130.199951  15.30  37.150002  31.855000  17.260000    1.68
# 2002-02-01  1106.729980  14.88  38.500000  29.170000  16.620001    1.76
# 2002-03-01  1147.390015  16.49  37.400002  30.155001  12.800000    1.83
# 2002-04-01  1076.920044  16.00  31.549999  26.129999  10.040000    1.75
# 2002-05-01  1067.140015  17.65  31.139999  25.455000   7.920000    1.76

# %%
def LogDiff(x):
    x_diff = 100*np.log(x/x.shift(1))
    x_diff = x_diff.dropna()
    return x_diff
    
data = pd.DataFrame({'ret_sandp' : LogDiff(data['SANDP']),
                    'ret_ford' : LogDiff(data['FORD']),
                    'USTB3M' : data['USTB3M']/12,
                    'ersandp' : LogDiff(data['SANDP']) - data['USTB3M']/12,
                    'erford' : LogDiff(data['FORD']) - data['USTB3M']/12})
data.head()
# Out:
#             ret_sandp   ret_ford    USTB3M   ersandp     erford
# Date
# 2002-01-01        NaN        NaN  0.140000       NaN        NaN
# 2002-02-01  -2.098486  -2.783480  0.146667 -2.245153  -2.930147
# 2002-03-01   3.608011  10.273611  0.152500  3.455511  10.121111
# 2002-04-01  -6.338466  -3.016541  0.145833 -6.484299  -3.162375
# 2002-05-01  -0.912297   9.814706  0.146667 -1.058964   9.668039

# %%
plt.figure(1, dpi=600)
plt.plot(data['ersandp'], label='ersandp')
plt.plot(data['erford'], label='erford')

plt.xlabel('Date')
plt.ylabel('ersandp/erford')
plt.title('Graph')
plt.grid(True)

plt.legend()
plt.show()

# %%
plt.figure(2, dpi=600)

plt.scatter(data['ersandp'], data['erford'])

plt.xlabel('ersandp')
plt.ylabel('erford')
plt.title('Graph')
plt.grid(True)

plt.show()

# %%
formula = 'erford ~ ersandp'
results = smf.ols(formula, data).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 erford   R-squared:                       0.337
# Model:                            OLS   Adj. R-squared:                  0.334
# Method:                 Least Squares   F-statistic:                     97.26
# Date:                Mon, 18 Sep 2023   Prob (F-statistic):           8.36e-19
# Time:                        13:34:37   Log-Likelihood:                -735.26
# No. Observations:                 193   AIC:                             1475.
# Df Residuals:                     191   BIC:                             1481.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9560      0.793     -1.205      0.230      -2.520       0.608
# ...

# %%
# F-test: hypothesis testing
formula = 'erford ~ ersandp'
hypotheses = 'ersandp = 1'

results = smf.ols(formula, data).fit()
f_test = results.f_test(hypotheses)
print(f_test)
# Out:
# <F test: F=21.560441202492147, p=6.365321036035383e-06, df_denom=191, df_num=1>

# %% [markdown]
# # 6 Sample output for multiple hypothesis tests

# %%
import pandas as pd
import numpy as np
import pickle

data = pd.read_excel('./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/capm.xls', index_col=0)

def LogDiff(x):
    x_diff = 100*np.log(x/x.shift(1))
    x_diff = x_diff.dropna()
    return x_diff
    
data = pd.DataFrame({'ret_sandp' : LogDiff(data['SANDP']),
                    'ret_ford' : LogDiff(data['FORD']),
                    'USTB3M' : data['USTB3M']/12,
                    'ersandp' : LogDiff(data['SANDP']) - data['USTB3M']/12,
                    'erford' : LogDiff(data['FORD']) - data['USTB3M']/12})

# %% [markdown]
# with open(abspath + 'capm.pickle', 'wb') as handle:
#     pickle.dump(data, handle)

# %%
import statsmodels.formula.api as smf
# F-test: multiple hypothesis tests
formula = 'erford ~ ersandp'
hypotheses = 'ersandp = Intercept = 1'

results = smf.ols(formula, data).fit()
f_test = results.f_test(hypotheses)
print(f_test)
# Out:
# <F test: F=12.94374019574068, p=5.349256152606822e-06, df_denom=191, df_num=2>

# %% [markdown]
# # 7 Muliple regression using an APT-style model

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

data = pd.read_excel('./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/macro.xls', index_col=0)
data.head()
# Out:
#             MICROSOFT       SANDP    CPI   INDPRO  M1SUPPLY   CCREDIT  \
# Date
# 1986-03-01   0.095486  238.899994  108.8  56.5414     624.3  606.7990
# 1986-04-01   0.111979  235.520004  108.6  56.5654     647.0  614.3669
# 1986-05-01   0.121528  247.350006  108.9  56.6850     645.7  621.9152
# 1986-06-01   0.106771  250.839996  109.5  56.4959     662.8  627.8910
# 1986-07-01   0.098958  236.119995  109.5  56.8096     673.4  633.6083
#
#             BMINUSA  USTB3M  USTB10Y
# Date
# 1986-03-01     1.50    6.76     7.78
# 1986-04-01     1.40    6.24     7.30
# 1986-05-01     1.20    6.33     7.71
# 1986-06-01     1.21    6.40     7.80
# 1986-07-01     1.28    6.00     7.30

# %%
def LogDiff(x):
    x_diff = 100*np.log(x/x.shift(1))
    x_diff = x_diff.dropna()
    return x_diff
   
data = pd.DataFrame({'dspread' : data['BMINUSA'] -                                  data['BMINUSA'].shift(1),
                    'dcredit' : data['CCREDIT'] - \
                                data['CCREDIT'].shift(1),
                    'dprod' : data['INDPRO'] - \
                              data['INDPRO'].shift(1),
                    'rmsoft' : LogDiff(data['MICROSOFT']),
                    'rsandp' : LogDiff(data['SANDP']),
                    'dmoney' : data['M1SUPPLY'] - \
                               data['M1SUPPLY'].shift(1),
                    'inflation' : LogDiff(data['CPI']),
                    'term' : data['USTB10Y'] - data['USTB3M'],
                    'dinflation' : LogDiff(data['CPI']) - \
                                   LogDiff(data['CPI']).shift(1),
                    'mustb3m' : data['USTB3M']/12,
                    'rterm' : (data['USTB10Y'] - data['USTB3M']) - \
                              (data['USTB10Y'] - data['USTB3M']).shift(1),
                    'ermsoft' : LogDiff(data['MICROSOFT']) - \
                                data['USTB3M']/12,
                    'ersandp' : LogDiff(data['SANDP']) - \
                                data['USTB3M']/12})
data.head()
# Out:
#             dspread  dcredit   dprod     rmsoft    rsandp  dmoney  inflation  \
# Date
# 1986-03-01      NaN      NaN     NaN        NaN       NaN     NaN        NaN
# 1986-04-01    -0.10   7.5679  0.0240  15.933171 -1.424918    22.7  -0.183993
# 1986-05-01    -0.20   7.5483  0.1196   8.183334  4.900851    -1.3   0.275862
# 1986-06-01     0.01   5.9758 -0.1891 -12.945833  1.401091    17.1   0.549452
# 1986-07-01     0.07   5.7173  0.3137  -7.599084 -6.047514    10.6   0.000000
#
#             term  dinflation   mustb3m  rterm    ermsoft   ersandp
# Date
# 1986-03-01  1.02         NaN  0.563333    NaN        NaN       NaN
# 1986-04-01  1.06         NaN  0.520000   0.04  15.413171 -1.944918
# 1986-05-01  1.38    0.459855  0.527500   0.32   7.655834  4.373351
# 1986-06-01  1.40    0.273590  0.533333   0.02 -13.479167  0.867757
# 1986-07-01  1.30   -0.549452  0.500000  -0.10  -8.099084 -6.547514

# %%
import pickle

with open('./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/macro.pickle', 'wb') as handle:
    pickle.dump(data, handle)
    
    
import pandas as pd
import pickle

# Excelファイルを読み込む
excel_path = "./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/macro.xls"  # あなたのExcelファイルのパスをここに指定
df = pd.read_excel(excel_path)

# データフレームをPickleファイルとして保存
pickle_path = "./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/macro.pickle"  # 保存したいPickleファイルのパスを指定
with open(pickle_path, 'wb') as f:
    pickle.dump(df, f)

# %% [markdown]
# formula = 'ermsoft ~ ersandp + dprod + dcredit + dinflation + dmoney + dspread + rterm'
# results = smf.ols(formula, data).fit()
# print(results.summary())

# %%
hypotheses = 'dprod = dcredit = dmoney = dspread = 0'

f_test = results.f_test(hypotheses)
print(f_test)
# Out:
# <F test: F=0.4138785595174923, p=0.7986453783432361, df_denom=375, df_num=4>

# %% [markdown]
# ## 7.1 Stepwise regression

# %%
import statsmodels.formula.api as smf
import pandas as pd
import numpy as np

def forward_selected(data, endog, exg):
    '''
    Linear model designed by forward selection based on p-values.

    Parameters:
    -----------
    data : pandas DataFrame with dependent and independent variables

    endog: string literals, dependent variable from the data
    
    exg: string literals, independent variable from the data
        
    Returns:
    --------
    res : an "optimal" fitted statsmodels linear model instance
           with an intercept selected by forward selection
    '''
    remaining = set(data.columns)
    remaining = [e for e in remaining if (e not in endog)&(e not in exg)]
    exg = [exg]

    scores_with_candidates = []
    for candidate in remaining:
        formula = '{} ~ {}'.format(endog,' + '.join(exg + [candidate]))

        score = smf.ols(formula, data).fit().pvalues[2]
        scores_with_candidates.append((score, candidate))
    scores_with_candidates.sort()

    for pval,candidate in scores_with_candidates:
        if pval < 0.2:    
            exg.append(candidate)

    formula = '{} ~ {}'.format(endog, ' + '.join(exg))
    res = smf.ols(formula, data).fit()
    return res

# %%
import pickle

abspath = './Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/'
with open(abspath + 'macro.pickle', 'rb') as handle:
    data = pickle.load(handle)

data = data.dropna() # drop the missing values for some columns
data.head()
# Out:
#         Date  MICROSOFT       SANDP    CPI   INDPRO  M1SUPPLY   CCREDIT  \
# 0 1986-03-01   0.095486  238.899994  108.8  56.5414     624.3  606.7990
# 1 1986-04-01   0.111979  235.520004  108.6  56.5654     647.0  614.3669
# 2 1986-05-01   0.121528  247.350006  108.9  56.6850     645.7  621.9152
# 3 1986-06-01   0.106771  250.839996  109.5  56.4959     662.8  627.8910
# 4 1986-07-01   0.098958  236.119995  109.5  56.8096     673.4  633.6083
#
#    BMINUSA  USTB3M  USTB10Y
# 0     1.50    6.76     7.78
# 1     1.40    6.24     7.30
# 2     1.20    6.33     7.71
# 3     1.21    6.40     7.80
# 4     1.28    6.00     7.30

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.08.08.png](attachment:f5415895-0a5b-4bec-a64f-47df45381ad6.png)

# %%
res = forward_selected(data,'ermsoft','ersandp')

print(res.model.formula)
# Out:
# ermsoft ~ ersandp + rterm + mustb3m + dinflation + inflation

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                ermsoft   R-squared:                       0.351
# Model:                            OLS   Adj. R-squared:                  0.343
# Method:                 Least Squares   F-statistic:                     40.83
# Date:                Mon, 18 Sep 2023   Prob (F-statistic):           1.55e-33
# Time:                        13:45:43   Log-Likelihood:                -1326.5
# No. Observations:                 383   AIC:                             2665.
# Df Residuals:                     377   BIC:                             2689.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0963      0.670     -0.144      0.886      -1.414       1.222
# ...

# %%
print(res.rsquared_adj)
# Out:
# 0.34268387020441105

# %% [markdown]
# # 8 Quantile regression

# %% [markdown]
# import pandas as pd
# import numpy as np
# import statsmodels.formula.api as smf
# import pickle
# import matplotlib.pyplot as plt
#
#  Excelファイルを読み込む
# excel_path = "./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/capm.xls"  # あなたのExcelファイルのパスをここに指定
# df = pd.read_excel(excel_path)
#
#  データフレームをPickleファイルとして保存
# pickle_path = "./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/capm.pickle"  # 保存したいPickleファイルのパスを指定
# with open(pickle_path, 'wb') as f:
#     pickle.dump(df, f)
#
# abspath = './Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/'
# with open(abspath + 'capm.pickle', 'rb') as handle:
#     data = pickle.load(handle)
# data = data.dropna()

# %% [markdown]
#  regression
#  quantile(50)
# res = smf.quantreg('erford ~ ersandp', data).fit(q=0.5)
# print(res.summary())

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.03.24.png](attachment:d1b6e0da-d80d-496c-82ea-0626a3a7a678.png)

# %% [markdown]
#  Simultaneous-quantile regression
#  10 20 30 40 50 60 70 80 90, ten quantiles
# quantiles = np.arange(0.10, 1.00, 0.10)
#
# for x in quantiles:
#     print('-----------------------------------------------')
#     print('{0:0.01f} quantile'.format(x))
#     res = smf.quantreg('erford ~ ersandp', data).fit(q=x)
#     print(res.summary())

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.11.25.png](attachment:6810c271-083f-4184-8f81-d54805cfa8ad.png)

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.12.38.png](attachment:467418c4-98d7-4834-819e-eb364fa5afb2.png)

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.12.49.png](attachment:1ee94215-f86c-4991-afca-6230a6a84100.png)

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.13.08.png](attachment:e51d355f-318f-4750-b591-3282d9ca8f0f.png)

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.13.19.png](attachment:f5bb87f5-f73d-4f1c-b4bf-703cd0a84685.png)

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.13.32.png](attachment:8be484f4-7c2f-4ddf-898c-e96e981f4b49.png)

# %% [markdown]
# def model_paras(data, quantiles):
#     '''
#     Parameters:
#     -----------
#         data: pandas DataFrame with dependent and independent variables
#         quantiles: quantile number
#
#     Returns:
#     -----------
#         quantreg_res: pandas DataFrame with model parameters for each
#                       quantile regression specification
#         y_hat: pandas DataFrame with all the fitted value of y
#     '''
#     parameters = []
#     y_pred = {}
#     for q in quantiles:
#         res = smf.quantreg('erford ~ ersandp', data).fit(q=q)
#         # obtain regression's parameters
#         alpha = res.params['Intercept']
#         beta = res.params['ersandp']
#         lb_pval = res.conf_int().loc['ersandp'][0]
#         ub_pval = res.conf_int().loc['ersandp'][1]
#         # obtain the fitted value of y
#         y_pred[q] = res.fittedvalues
#         # save results to lists
#         parameters.append((q,alpha,beta,lb_pval,ub_pval))
#
#     quantreg_res = pd.DataFrame(parameters, columns=['q', 'alpha',                                                      'beta','lb','ub'])
#     y_hat = pd.DataFrame(y_pred)
#     return quantreg_res, y_hat

# %% [markdown]
# quantreg_paras, y_hats = model_paras(data, quantiles)

# %% [markdown]
# print(quantreg_paras)

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.15.12.png](attachment:2fe7fb9b-c30f-4b07-9111-ec152bb2fee6.png)

# %% [markdown]
# y_hats.head()

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.15.33.png](attachment:71a5a79c-ac7a-44ff-963e-19be6612392e.png)

# %% [markdown]
# plt.figure(1, dpi=600)
# for i in quantreg_paras.q:
#     x = data['ersandp']
#     y = y_hats[i]
#     if i == 0.50:
#         plt.plot(x,y,color='red')
#     else:
#         plt.plot(x,y,color='grey')
#
#
# plt.ylabel('ersandp')
# plt.xlabel('erford')
# plt.show()

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.16.00.png](attachment:e474a71e-5e92-4121-96e1-ce20fd9b0824.png)

# %% [markdown]
# # 9 Calculating principal components

# %% [markdown]
# from numpy import mean,cov,cumsum,dot,linalg,std,sort
# import pandas as pd
# import matplotlib.pyplot as plt
#
# data = pd.read_excel('./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/fred.xls', index_col=0)
#
# data.head()

# %% [markdown]
# def princomp(data):
#     '''
#     Computing eigenvalues and eigenvectors of covariance matrix
#
#     Parameters:
#     -----------
#     data: the m-by-n DataFrame which corresponds m rows of observations
#           and n columns of variables.
#
#     Returns:
#     -----------
#     coeff: a n-by-n matrix (eigenvectors) where it contains all coefficients
#            of principal component for each variable.
#
#     latent: a vector of the eigenvalues
#     '''
#
#     M = data.apply(lambda x: (x-mean(x))/std(x) ) # normalize
#
#     # Note: cov inputs require a column vector;
#     # That is each row of m represents a variable,
#     # and each column is a single observation of all those variables
#     # To tackle this, simply add argument rowvar=True
#     # or transpose M matrix
#     [latent,coeff] = linalg.eig(cov(M.transpose()))
#     # attention: latent (eigenvalues) is not always sorted
#     latent = sort(latent)[::-1]
#
#     # convert arrays to DataFrame or Series
#     coeff = pd.DataFrame(coeff.T, columns=data.columns)
#     latent = pd.Series(latent, name='Eigenvalue')
#
#     return coeff, latent

# %% [markdown]
# coeff, latent = princomp(data)

# %% [markdown]
# coeff

# %% [markdown]
# ![スクリーンショット 2023-09-18 15.19.37.png](attachment:1e402c28-8ca6-4f12-924e-01ad1e423b25.png)

# %% [markdown]
# perc_lat = cumsum(latent)/sum(latent)
# print(perc_lat)

# %% [markdown]
# ![スクリーンショット 2023-09-18 15.19.53.png](attachment:15e548c0-2223-4650-b368-91c2d35da45f.png)

# %% [markdown]
# plt.figure(1, dpi=600)
# plt.stem(range(len(perc_lat)),perc_lat,'--b')
# plt.ylabel('Percentage of Eeigenvalues')
# plt.xlabel('The number of components')
# plt.show()

# %% [markdown]
# ![スクリーンショット 2023-09-18 15.19.22.png](attachment:40d4dc7e-e83d-4a94-90f7-c52ef9aaca14.png)

# %% [markdown]
# # 10 Diagnostic testing

# %% [markdown]
# ## 10.1 Testing for heteroscedasticity

# %% [markdown]
# import statsmodels.formula.api as smf
# import statsmodels.stats.api as sms
# from statsmodels.compat import lzip
# import pickle
#
# with open('./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/macro.xls', 'rb') as handle:
#     data = pickle.load(handle)
#
# data = data.dropna() # drop the missing values for some columns

# %% [markdown]
#  durbin_watson
# formula = 'ermsoft ~ ersandp + dprod + dcredit + dinflation + dmoney + dspread + rterm'
# results = smf.ols(formula, data).fit()
#
# residuals = results.resid
# sms.durbin_watson(residuals)

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.23.39.png](attachment:90ecf0b6-de59-4fc5-89a5-174a43e61217.png)

# %% [markdown]
# name = ['Lagrange multiplier statistic', 'p-value',
#         'f-value', 'f p-value']
# results1 = sms.acorr_breusch_godfrey(results, 10)
# lzip(name, results1)

# %% [markdown]
# ![スクリーンショット 2023-09-18 15.18.21.png](attachment:0cad7db3-bc2d-4f70-8cca-49bcba40abf1.png)

# %% [markdown]
# ## 10.2 Using White's modified standard error estimates

# %% [markdown]
# import statsmodels.formula.api as smf
# import pickle
#
# with open('./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/macro.xls', 'rb') as handle:
#     data = pickle.load(handle)
#
# data = data.dropna() # drop the missing values for some columns

# %% [markdown]
# formula = 'ermsoft ~ ersandp + dprod + dcredit +                      dinflation + dmoney + dspread + rterm'
# results = smf.ols(formula, data).fit(cov_type='HC1')
# print(results.summary())

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.26.41.png](attachment:7e12ff42-9a71-4eb0-a3d2-70cb598642bc.png)

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.27.06.png](attachment:2b138e14-e4ec-4987-8619-a0798b320b92.png)

# %% [markdown]
# ## 10.3 The Newey-West procedure for estimating standard errors

# %% [markdown]
# import statsmodels.formula.api as smf
# import pickle
#
# with open('./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/macro.xls', 'rb') as handle:
#     data = pickle.load(handle)
#
# data = data.dropna() # drop the missing values for some columns

# %% [markdown]
# formula = 'ermsoft ~ ersandp + dprod + dcredit + dinflation + dmoney + dspread + rterm'
# results = smf.ols(formula, data).fit(cov_type='HAC',
#                                      cov_kwds={'maxlags':6,'use_correction':True})
# print(results.summary())

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.29.11.png](attachment:81a786fc-2f1a-459a-8724-ce9231700d2a.png)

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.29.19.png](attachment:195c7bb6-62b4-4317-921c-19061acff104.png)

# %% [markdown]
# ## 10.4 Autocorrelation and dynamic models

# %% [markdown]
# import statsmodels.formula.api as smf
# import statsmodels.stats.api as sms
# from statsmodels.compat import lzip
# import pickle
#
# with open('./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/macro.xls', 'rb') as handle:
#     data = pickle.load(handle)
#
# data = data.dropna() # drop the missing values for some columns

# %% [markdown]
# - durbin_watson
# formula = 'ermsoft ~ ersandp + dprod + dcredit + dinflation + dmoney + dspread + rterm'
# results = smf.ols(formula, data).fit()
#
# residuals = results.resid
# sms.durbin_watson(residuals)

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.32.30.png](attachment:e0e74e79-4cba-4d0a-af2b-5b646267ac34.png)

# %% [markdown]
# name = ['Lagrange multiplier statistic', 'p-value',
#         'f-value', 'f p-value']
# results1 = sms.acorr_breusch_godfrey(results, 10)
# lzip(name, results1)

# %% [markdown]
# ![スクリーンショット 2023-09-18 15.18.39.png](attachment:75a0f3f8-453a-4be5-bcde-0a65b226e881.png)

# %% [markdown]
# ## 10.5 Testing for non-normality

# %% [markdown]
# import statsmodels.formula.api as smf
# import statsmodels.stats.api as sms
# from statsmodels.compat import lzip
# import matplotlib.pyplot as plt
# import pickle
#
# with open('./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/macro.xls', 'rb') as handle:
#     data = pickle.load(handle)
#
# data = data.dropna() # drop the missing values for some columns

# %% [markdown]
# formula = 'ermsoft ~ ersandp + dprod + dcredit + dinflation + dmoney + dspread + rterm'
# results = smf.ols(formula, data).fit()
# residuals = results.resid
#
# plt.figure(1, dpi=600)
# plt.hist(residuals,20,edgecolor='black',linewidth=1.2)
# plt.xlabel('Residuals')
# plt.ylabel('Density')
# plt.show()

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.37.49.png](attachment:f7a3c350-eac1-4926-846e-c2dc116e5ef1.png)

# %% [markdown]
# name = ['Jarque-Bera', 'Chi^2 two-tail prob.', 'Skew', 'Kurtosis']
# test = sms.jarque_bera(residuals)
# lzip(name, test)

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.38.18.png](attachment:3da0a8ca-1fa0-4dfc-9747-6acc03f5a907.png)

# %% [markdown]
# ## 10.6 Dummy variables construction and use

# %% [markdown]
# import statsmodels.formula.api as smf
# import matplotlib.pyplot as plt
# import numpy as np
# import pickle
#
# with open('./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/macro.xls', 'rb') as handle:
#     data = pickle.load(handle)
#
# data = data.dropna() # drop the missing values for some columns

# %% [markdown]
# - regression
# formula = 'ermsoft ~ ersandp + dprod + dcredit + dinflation + dmoney + dspread + rterm'
# results = smf.ols(formula, data).fit()
# y_fitted = results.fittedvalues
# residuals = results.resid

# %% [markdown]
# plt.figure(1,dpi=600)
# plt.plot(residuals, label='resid')
# plt.plot(y_fitted, label='linear prediction')
# plt.xlabel('Date')
# plt.ylabel('Residuals')
# plt.grid(True)
# plt.legend()
# plt.show()

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.41.40.png](attachment:dbb49253-de8e-4e0d-a94e-e535b9f49aaa.png)

# %% [markdown]
# residuals.nsmallest(2)

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.42.09.png](attachment:39de013a-8b7c-440f-8a58-0a727aac15d8.png)

# %% [markdown]
# data['APR00DUM'] = np.where(data.index == '2000-4-1', 1, 0)
# data['DEC00DUM'] = np.where(data.index == '2000-12-1', 1, 0)
#
# - regression
# formula = 'ermsoft ~ ersandp + dprod + dcredit + dinflation + dmoney + dspread + rterm +                      APR00DUM + DEC00DUM'
# results = smf.ols(formula, data).fit()
# print(results.summary())

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.42.40.png](attachment:20cca6cb-638d-4454-92c4-e6ecb7347d84.png)

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.42.46.png](attachment:c57ba446-d797-4ab3-8fce-a158989442fd.png)

# %% [markdown]
# ## 10.7 Multicollinearity

# %% [markdown]
# import pickle
#
# with open('./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/macro.xls', 'rb') as handle:
#     data = pickle.load(handle)
#
# data = data.dropna() # drop the missing values for some columns

# %% [markdown]
# data = data[['dprod','dcredit','dinflation','dmoney','dspread','rterm']]
# data.corr()

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.44.06.png](attachment:06331316-70e8-40c6-91f3-d354f275b628.png)

# %% [markdown]
# ## 10.8 The RESET test for functional form

# %% [markdown]
# from statsmodels.stats.outliers_influence import reset_ramsey
# import statsmodels.formula.api as smf
# import pickle
#
# with open('./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/macro.xls', 'rb') as handle:
#     data = pickle.load(handle)
#
# data = data.dropna() # drop the missing values for some columns

# %% [markdown]
# formula = 'ermsoft ~ ersandp + dprod + dcredit + dinflation + dmoney + dspread + rterm'
# results = smf.ols(formula, data).fit()
#
# reset_ramsey(results,degree=4)

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.45.45.png](attachment:681ba078-bdf7-4635-9ab4-edd69ab2298f.png)

# %% [markdown]
# ## 10.9 Stability tests

# %% [markdown]
# import statsmodels.stats.api as sms
# import statsmodels.formula.api as smf
# from statsmodels.compat import lzip
# import pickle
# import pandas as pd
# import matplotlib.pyplot as plt
#
# data = pd.read_excel('./Desktop/01_school/Fukuhara-seminar_Summer2023/excel_data/macro.xls')
#
# data = data.dropna() # drop the missing values for some columns

# %% [markdown]
# def get_rss(data):
#     '''
#     inputs:
#         data: a pandas DataFrame of independent and dependent variable
#     outputs:
#         rss: the sum of residuals
#         N: the observations of inputs
#         K: total number of parameters
#     '''
#     formula = 'ermsoft ~ ersandp + dprod + dcredit +                          dinflation + dmoney + dspread + rterm'
#     results = smf.ols(formula, data).fit()
#     rss = (results.resid**2).sum() # obtain the residuals sum of square
#     N = results.nobs
#     K = results.df_model
#     return rss, N, K

# %% [markdown]
#  split samples
# data1 = data[:'1996-01-01']
# data2 = data['1996-01-01':]
#
#  get rss of whole sample
# RSS_total, N_total, K_total = get_rss(data)
#  get rss of the first part of sample
# RSS_1, N_1, K_1 = get_rss(data1)
#  get rss of the second part of sample
# RSS_2, N_2, K_2 = get_rss(data2)
#
# nominator = (RSS_total - (RSS_1 + RSS_2)) / K_total
# denominator = (RSS_1 + RSS_2) / (N_1 + N_2 - 2*K_total)
#
# result = nominator/denominator

# %% [markdown]
# result

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.50.09.png](attachment:e5c764d5-3dbc-4771-af57-ecbc9340ddce.png)

# %% [markdown]
# formula = 'ermsoft ~ ersandp + dprod + dcredit +                      dinflation + dmoney + dspread + rterm'
# results = smf.ols(formula, data).fit()
#
# name = ['test statistic', 'pval', 'crit']
# test = sms.breaks_cusumolsresid(olsresidual = results.resid,                                ddof = results.df_model)
# lzip(name, test)

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.50.48.png](attachment:afab9e2f-af27-48bb-89c4-86be3fb70134.png)

# %% [markdown]
# def recursive_reg(variable, i, interval):
#     '''
#     Parameters:
#     -----------
#         variable: the string literals of a variable name in regression
#                   formula.
#         i: the serial number of regression.
#         interval: the number of consective data points in initial sample
#
#     Returns:
#     -----------
#         coeff: the coefficient estimation of the variable
#         se: the standard errors of the variable
#     '''
#     formula = 'ermsoft ~ ersandp + dprod + dcredit +                      dinflation + dmoney + dspread + rterm'
#     results = smf.ols(formula, data.iloc[:i+interval]).fit()
#     coeff = results.params[variable]
#     se = results.bse[variable]
#
#     return coeff, se

# %% [markdown]
# parameters = []
# for i in range(373):
#     coeff, se = recursive_reg('ersandp', i, 11)
#
#     parameters.append((coeff,se))
#
# parameters = pd.DataFrame(parameters, columns=['coeff','se'], index = data[:-10].index)
#
# parameters['ersandp + 2*se'] = parameters['coeff'] + 2*parameters['se']
# parameters['ersandp - 2*se'] = parameters['coeff'] - 2*parameters['se']
#
# plt.figure(1, dpi=600)
# plt.plot(parameters['coeff'], label=r'$\beta_{ersandp}$')
# plt.plot(parameters['ersandp + 2*se'], label=r'$\beta_{ersandp} + 2*SE$',         linestyle='dashed')
# plt.plot(parameters['ersandp - 2*se'], label=r'$\beta_{ersandp} - 2*SE$',         linestyle='dashed')
#
# plt.xlabel('Date')
# plt.grid(True)
# plt.legend()
# plt.show()

# %% [markdown]
# ![スクリーンショット 2023-09-18 14.52.16.png](attachment:495655eb-3906-4ea2-bf99-e550b92ff49c.png)
